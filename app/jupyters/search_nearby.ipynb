# %%
import os

import pandas as pd
import numpy as np

import warnings
warnings.filterwarnings('ignore')

# %%
DATA_DIR = '../data/'

data = pd.read_csv(os.path.join(DATA_DIR, 'search_nearby_1.csv'))
print(data.shape)
print(data.columns)
data.head()
# Out:
# (16, 20)
# Index(['geometry_location_lat', 'geometry_location_lng',
#        'geometry_viewport_northeast_lat', 'geometry_viewport_northeast_lng',
#        'geometry_viewport_southwest_lat', 'geometry_viewport_southwest_lng',
#        'icon', 'id', 'name', 'opening_hours_open_now', 'photos', 'place_id',
#        'plus_code_compound_code', 'plus_code_global_code', 'price_level',
#        'rating', 'reference', 'scope', 'types', 'vicinity'],
#       dtype='object')
#    geometry_location_lat  geometry_location_lng  \
# 0              50.448074              30.458457
# 1              50.446403              30.450569
# 2              50.446834              30.451885
# 3              50.446821              30.453612
# 4              50.447007              30.453119
#
#    geometry_viewport_northeast_lat  geometry_viewport_northeast_lng  \
# 0                        50.449423                        30.459806
# 1                        50.447649                        30.451983
# ...

# %%
data.icon[1]
# Out:
# 'https://maps.gstatic.com/mapfiles/place_api/icons/bar-71.png'

# %%
data
# Out:
#     geometry_location_lat  geometry_location_lng  \
# 0               50.448074              30.458457
# 1               50.446403              30.450569
# 2               50.446834              30.451885
# 3               50.446821              30.453612
# 4               50.447007              30.453119
# 5               50.446768              30.454270
# 6               50.446736              30.453687
# 7               50.446920              30.453037
# 8               50.446704              30.454333
# 9               50.446701              30.454344
# 10              50.447182              30.456279
# 11              50.447904              30.451582
# 12              50.447565              30.458542
# 13              50.444413              30.451538
# 14              50.444366              30.451619
# 15              50.448669              30.449024
#
#     geometry_viewport_northeast_lat  geometry_viewport_northeast_lng  \
# ...
